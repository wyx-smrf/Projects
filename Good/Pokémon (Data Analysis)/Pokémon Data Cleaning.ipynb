# %% [markdown]
# # Pokémon Simple Beginner Project

# %% [markdown]
# ---

# %%
import pandas as pd

df = pd.read_csv('PokemonData.csv')

# %%
df.head(3)
# Out:
#         Name                 Type  Total  HP  Attack  Defense  Sp. Atk  \
# 0  Bulbasaur  ['Grass', 'Poison']    318  45      49       49       65
# 1    Ivysaur  ['Grass', 'Poison']    405  60      62       63       80
# 2   Venusaur  ['Grass', 'Poison']    525  80      82       83      100
#
#    Sp. Def  Speed                                      url  \
# 0       65     45  https://pokemondb.net/pokedex/bulbasaur
# 1       80     60    https://pokemondb.net/pokedex/ivysaur
# 2      100     80   https://pokemondb.net/pokedex/venusaur
#
#                                                 icon
# 0  https://img.pokemondb.net/sprites/sword-shield...
# 1  https://img.pokemondb.net/sprites/sword-shield...
# 2  https://img.pokemondb.net/sprites/sword-shield...

# %% [markdown]
# ---

# %% [markdown]
# # 1. Remove unwanted columns

# %%
df = df.drop(columns = ['url','icon'])
df
# Out:
#            Name                  Type  Total   HP  Attack  Defense  Sp. Atk  \
# 0     Bulbasaur   ['Grass', 'Poison']    318   45      49       49       65
# 1       Ivysaur   ['Grass', 'Poison']    405   60      62       63       80
# 2      Venusaur   ['Grass', 'Poison']    525   80      82       83      100
# 3    Charmander          ['Fire', '']    309   39      52       43       60
# 4    Charmeleon          ['Fire', '']    405   58      64       58       80
# ..          ...                   ...    ...  ...     ...      ...      ...
# 893   Regieleki      ['Electric', '']    580   80     100       50      100
# 894   Regidrago        ['Dragon', '']    580  200     100       50      100
# 895   Glastrier           ['Ice', '']    580  100     145      130       65
# 896   Spectrier         ['Ghost', '']    580  100      65       60      145
# 897     Calyrex  ['Psychic', 'Grass']    500  100      80       80       80
#
#      Sp. Def  Speed
# 0         65     45
# 1         80     60
# 2        100     80
# 3         50     65
# 4         65     80
# ..       ...    ...
# 893       50    200
# 894       50     80
# 895      110     30
# 896       80    130
# 897       80     80
#
# [898 rows x 9 columns]

# %% [markdown]
# ---

# %% [markdown]
# # 2. Separate Type column into two

# %%
df[['Type 1', 'Type 2']] = df['Type'].str.split(",", expand=True)
    # Type 1 and Type 2 will be the name of the new column
    # str.split(",") comma is used as the delimiter to separate the data
    # str.split(expand=True) the Type 1 and Type 2 will be created as a new column
    
df
# Out:
#            Name                  Type  Total   HP  Attack  Defense  Sp. Atk  \
# 0     Bulbasaur   ['Grass', 'Poison']    318   45      49       49       65
# 1       Ivysaur   ['Grass', 'Poison']    405   60      62       63       80
# 2      Venusaur   ['Grass', 'Poison']    525   80      82       83      100
# 3    Charmander          ['Fire', '']    309   39      52       43       60
# 4    Charmeleon          ['Fire', '']    405   58      64       58       80
# ..          ...                   ...    ...  ...     ...      ...      ...
# 893   Regieleki      ['Electric', '']    580   80     100       50      100
# 894   Regidrago        ['Dragon', '']    580  200     100       50      100
# 895   Glastrier           ['Ice', '']    580  100     145      130       65
# 896   Spectrier         ['Ghost', '']    580  100      65       60      145
# 897     Calyrex  ['Psychic', 'Grass']    500  100      80       80       80
#
#      Sp. Def  Speed       Type 1      Type 2
# 0         65     45     ['Grass'   'Poison']
# 1         80     60     ['Grass'   'Poison']
# 2        100     80     ['Grass'   'Poison']
# 3         50     65      ['Fire'         '']
# 4         65     80      ['Fire'         '']
# ..       ...    ...          ...         ...
# 893       50    200  ['Electric'         '']
# 894       50     80    ['Dragon'         '']
# 895      110     30       ['Ice'         '']
# 896       80    130     ['Ghost'         '']
# 897       80     80   ['Psychic'    'Grass']
#
# [898 rows x 11 columns]

# %% [markdown]
# ---

# %% [markdown]
# # 3. Remove unwanted characters (brackets)

# %%
df['Type 1'] = df['Type 1'].str.strip(r"[' '")
df['Type 2'] = df['Type 2'].str.strip(r"' ']")
    # .strip(r"' ']") removes the metacharacter/regex characters 
    
df = df.drop(['Type'], axis=1)
     # Remove unwanted columns.

df.head(10)
# Out:
#          Name  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed Type 1  \
# 0   Bulbasaur    318  45      49       49       65       65     45  Grass
# 1     Ivysaur    405  60      62       63       80       80     60  Grass
# 2    Venusaur    525  80      82       83      100      100     80  Grass
# 3  Charmander    309  39      52       43       60       50     65   Fire
# 4  Charmeleon    405  58      64       58       80       65     80   Fire
# 5   Charizard    534  78      84       78      109       85    100   Fire
# 6    Squirtle    314  44      48       65       50       64     43  Water
# 7   Wartortle    405  59      63       80       65       80     58  Water
# 8   Blastoise    530  79      83      100       85      105     78  Water
# 9    Caterpie    195  45      30       35       20       20     45    Bug
#
#    Type 2
# 0  Poison
# 1  Poison
# 2  Poison
# 3
# 4
# 5  Flying
# 6
# 7
# 8
# 9

# %% [markdown]
# ---

# %% [markdown]
# # 4. Move columns into specified position

# %%
# Series Type

# df.insert(position_index, 'New_column_name', column_data)

df.insert(1, "Type 1", df.pop("Type 1"))

df.insert(2, "Type 2", df.pop("Type 2"))

df.insert(9, "Total", df.pop("Total"))

df = df

df
# Out:
#            Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0     Bulbasaur     Grass  Poison   45      49       49       65       65
# 1       Ivysaur     Grass  Poison   60      62       63       80       80
# 2      Venusaur     Grass  Poison   80      82       83      100      100
# 3    Charmander      Fire           39      52       43       60       50
# 4    Charmeleon      Fire           58      64       58       80       65
# ..          ...       ...     ...  ...     ...      ...      ...      ...
# 893   Regieleki  Electric           80     100       50      100       50
# 894   Regidrago    Dragon          200     100       50      100       50
# 895   Glastrier       Ice          100     145      130       65      110
# 896   Spectrier     Ghost          100      65       60      145       80
# 897     Calyrex   Psychic   Grass  100      80       80       80       80
#
#      Speed  Total
# 0       45    318
# 1       60    405
# 2       80    525
# 3       65    309
# 4       80    405
# ..     ...    ...
# 893    200    580
# 894     80    580
# 895     30    580
# 896    130    580
# 897     80    500
#
# [898 rows x 10 columns]

# %% [markdown]
# ---

# %% [markdown]
# # 5. Determine the summary statistics.

# %%
df.describe().round(2)
    # .describe() returns the summary statistics of the dataframe
    # .round() returns the .describe() in two decimal places
# Out:
#            HP  Attack  Defense  Sp. Atk  Sp. Def   Speed   Total
# count  898.00  898.00   898.00   898.00   898.00  898.00  898.00
# mean    69.03   76.59    71.92    69.68    69.91   65.95  423.08
# std     26.21   29.78    29.60    29.37    27.09   28.46  112.10
# min      1.00    5.00     5.00    10.00    20.00    5.00  175.00
# 25%     50.00   55.00    50.00    46.25    50.00   45.00  320.00
# 50%     65.00   75.00    67.00    65.00    65.00   65.00  440.00
# 75%     80.00   95.00    90.00    90.00    85.00   85.00  500.00
# max    255.00  181.00   230.00   173.00   230.00  200.00  720.00

# %% [markdown]
# ---

# %% [markdown]
# # 6. Determine the elements present in Type 1

# %%
df[['Type 1']].drop_duplicates().reset_index()
    # .drop_duplicates() returns the values in Type 1 without duplicates
    # .reset_index() resets the index to start in ascending order
# Out:
#     index    Type 1
# 0       0     Grass
# 1       3      Fire
# 2       6     Water
# 3       9       Bug
# 4      15    Normal
# 5      22    Poison
# 6      24  Electric
# 7      26    Ground
# 8      34     Fairy
# 9      55  Fighting
# 10     62   Psychic
# 11     73      Rock
# 12     91     Ghost
# 13    123       Ice
# 14    146    Dragon
# 15    196      Dark
# 16    207     Steel
# 17    640    Flying

# %% [markdown]
# ---

# %% [markdown]
# # 7. Determine the count of each elements in Type 1

# %%
df[['Type 1']].value_counts()
# Out:
# Type 1
# Water       123
# Normal      109
# Grass        86
# Bug          75
# Fire         58
# Psychic      58
# Rock         50
# Electric     49
# Fighting     36
# Dark         36
# Ground       35
# Poison       35
# Ghost        31
# Dragon       31
# Steel        30
# Ice          28
# Fairy        21
# Flying        7
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # 8. Separate dual elemented from single elemented Pokémons

# %%
df['Type 2'] = df['Type 2'].replace('', pd.NA)
    # .replace('', pd.NA) replaces the white space with missing value (NA).

df
# Out:
#            Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0     Bulbasaur     Grass  Poison   45      49       49       65       65
# 1       Ivysaur     Grass  Poison   60      62       63       80       80
# 2      Venusaur     Grass  Poison   80      82       83      100      100
# 3    Charmander      Fire    <NA>   39      52       43       60       50
# 4    Charmeleon      Fire    <NA>   58      64       58       80       65
# ..          ...       ...     ...  ...     ...      ...      ...      ...
# 893   Regieleki  Electric    <NA>   80     100       50      100       50
# 894   Regidrago    Dragon    <NA>  200     100       50      100       50
# 895   Glastrier       Ice    <NA>  100     145      130       65      110
# 896   Spectrier     Ghost    <NA>  100      65       60      145       80
# 897     Calyrex   Psychic   Grass  100      80       80       80       80
#
#      Speed  Total
# 0       45    318
# 1       60    405
# 2       80    525
# 3       65    309
# 4       80    405
# ..     ...    ...
# 893    200    580
# 894     80    580
# 895     30    580
# 896    130    580
# 897     80    500
#
# [898 rows x 10 columns]

# %%
s_elem = df[df['Type 2'].isna()]

s_elem
# Out:
#            Name    Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 3    Charmander      Fire   <NA>   39      52       43       60       50
# 4    Charmeleon      Fire   <NA>   58      64       58       80       65
# 6      Squirtle     Water   <NA>   44      48       65       50       64
# 7     Wartortle     Water   <NA>   59      63       80       65       80
# 8     Blastoise     Water   <NA>   79      83      100       85      105
# ..          ...       ...    ...  ...     ...      ...      ...      ...
# 890       Kubfu  Fighting   <NA>   60      90       60       53       50
# 893   Regieleki  Electric   <NA>   80     100       50      100       50
# 894   Regidrago    Dragon   <NA>  200     100       50      100       50
# 895   Glastrier       Ice   <NA>  100     145      130       65      110
# 896   Spectrier     Ghost   <NA>  100      65       60      145       80
#
#      Speed  Total
# 3       65    309
# 4       80    405
# 6       43    314
# 7       58    405
# 8       78    530
# ..     ...    ...
# 890     72    385
# 893    200    580
# 894     80    580
# 895     30    580
# 896    130    580
#
# [454 rows x 10 columns]

# %%
d_elem = df[df['Type 2'].notna()]

d_elem
# Out:
#            Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0     Bulbasaur     Grass  Poison   45      49       49       65       65
# 1       Ivysaur     Grass  Poison   60      62       63       80       80
# 2      Venusaur     Grass  Poison   80      82       83      100      100
# 5     Charizard      Fire  Flying   78      84       78      109       85
# 11   Butterfree       Bug  Flying   60      45       50       90       80
# ..          ...       ...     ...  ...     ...      ...      ...      ...
# 888   Zamazenta  Fighting   Steel   92     130      145       80      145
# 889   Eternatus    Poison  Dragon  140      85       95      145       95
# 891     Urshifu  Fighting    Dark  100     130      100       63       60
# 892      Zarude      Dark   Grass  105     120      105       70       95
# 897     Calyrex   Psychic   Grass  100      80       80       80       80
#
#      Speed  Total
# 0       45    318
# 1       60    405
# 2       80    525
# 5      100    534
# 11      70    395
# ..     ...    ...
# 888    128    720
# 889    130    690
# 891     97    550
# 892    105    600
# 897     80    500
#
# [444 rows x 10 columns]

# %% [markdown]
# ---

# %% [markdown]
# # 9. Sort names in alphabetical order

# %%
df.sort_values(by=['Name'], ascending=True)
# Out:
#           Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 459  Abomasnow    Grass     Ice   90      92       75       92       85
# 62        Abra  Psychic    <NA>   25      20       15      105       55
# 358      Absol     Dark    <NA>   65     130       60       75       60
# 616   Accelgor      Bug    <NA>   80      70       40      100       60
# 680  Aegislash    Steel   Ghost   60      50      140       50      140
# ..         ...      ...     ...  ...     ...      ...      ...      ...
# 570    Zoroark     Dark    <NA>   60     105       60      120       60
# 569      Zorua     Dark    <NA>   40      65       40       80       40
# 40       Zubat   Poison  Flying   40      45       35       30       40
# 633   Zweilous     Dark  Dragon   72      85       70       65       70
# 717    Zygarde   Dragon  Ground  108     100      121       81       95
#
#      Speed  Total
# 459     60    494
# 62      90    310
# 358     75    465
# 616    145    495
# 680     60    500
# ..     ...    ...
# 570    105    510
# 569     65    330
# 40      55    245
# 633     58    420
# 717     95    600
#
# [898 rows x 10 columns]

# %% [markdown]
# ---

# %% [markdown]
# # 10. Save cleaned dataset

# %% [raw]
# df.to_csv('pokémon_cleaned_dataset.csv')

# %% [markdown]
# ---

# %% [markdown]
# # Extra

# %%
df.groupby('Type 1')['Total'].sum()
# Out:
# Type 1
# Bug         28011
# Dark        15708
# Dragon      15227
# Electric    21295
# Fairy        8994
# Fighting    15437
# Fire        25733
# Flying       2940
# Ghost       13443
# Grass       35081
# Ground      14843
# Ice         12103
# Normal      43231
# Poison      14436
# Psychic     26087
# Rock        21967
# Steel       14083
# Water       51308
# Name: Total, dtype: int64

# %%
df.groupby('Type 1')['Total'].agg(sum)
# Out:
# Type 1
# Bug         28011
# Dark        15708
# Dragon      15227
# Electric    21295
# Fairy        8994
# Fighting    15437
# Fire        25733
# Flying       2940
# Ghost       13443
# Grass       35081
# Ground      14843
# Ice         12103
# Normal      43231
# Poison      14436
# Psychic     26087
# Rock        21967
# Steel       14083
# Water       51308
# Name: Total, dtype: int64
